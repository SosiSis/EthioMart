# %%
import pandas as pd
import os
import re
json_folder = "../data/preprocessed"

# %%
df=pd.read_csv("../data/preprocessed/clean_data.csv")

# %%
df.head()
# Out:
#    Unnamed: 0        Channel Title    Channel Username    ID  \
# 0           5  Sheger online-store  @Shageronlinestore  5328
# 1           6  Sheger online-store  @Shageronlinestore  5327
# 2           7  Sheger online-store  @Shageronlinestore  5326
# 3           8  Sheger online-store  @Shageronlinestore  5325
# 4          10  Sheger online-store  @Shageronlinestore  5323
#
#                                              Message  \
# 0  3   \n\nእስከ 260° ሙቀት መቆቆም የሚችል\n      \n      ...
# 1   \n\n ጊዜ ቆጣቢ ስላይስ ማድረጊያ \n  ለእጅ ሴፍቲ ተመራጭ\n  ለድ...
# 2      \n          \n\n  ,  ,   - \n\n           ...
# 3      \n          \n\n  ,  ,   - \n\n           ...
# 4    31    ,, \n\n        ዋጋ:-3000ብር\n\nውስን ፍሬ ነው...
#
#                         Date                          Media Path
# 0  2024-09-20 11:50:02+00:00  photos/@Shageronlinestore_5328.jpg
# 1  2024-09-20 08:11:40+00:00                                 NaN
# 2  2024-09-20 05:23:18+00:00                                 NaN
# 3  2024-09-20 05:21:14+00:00  photos/@Shageronlinestore_5325.jpg
# 4  2024-09-19 13:54:46+00:00  photos/@Shageronlinestore_5323.jpg

# %%
from amseg.amharicSegmenter import AmharicSegmenter

# %%
sent_punct = []
word_punct = []
segmenter = AmharicSegmenter(sent_punct, word_punct)

# Define the function to tokenize Amharic text
def tokenize_amharic(text):
    words = segmenter.amharic_tokenizer(text)  # Tokenizing the text into words
    return words  # Returning the tokenized words

# %%
# Apply the function to the 'cleaned_text' column to create a new 'tokenize' column
df["tokenize"] = df["Message"].apply(tokenize_amharic)

# Display the updated DataFrame
print(df.head())
# Out:
#    Unnamed: 0        Channel Title    Channel Username    ID  \
# 0           5  Sheger online-store  @Shageronlinestore  5328
# 1           6  Sheger online-store  @Shageronlinestore  5327
# 2           7  Sheger online-store  @Shageronlinestore  5326
# 3           8  Sheger online-store  @Shageronlinestore  5325
# 4          10  Sheger online-store  @Shageronlinestore  5323
#
#                                              Message  \
# 0  3   \n\nእስከ 260° ሙቀት መቆቆም የሚችል\n      \n      ...
# 1   \n\n ጊዜ ቆጣቢ ስላይስ ማድረጊያ \n  ለእጅ ሴፍቲ ተመራጭ\n  ለድ...
# 2      \n          \n\n  ,  ,   - \n\n           ...
# 3      \n          \n\n  ,  ,   - \n\n           ...
# 4    31    ,, \n\n        ዋጋ:-3000ብር\n\nውስን ፍሬ ነው...
#
#                         Date                          Media Path  \
# 0  2024-09-20 11:50:02+00:00  photos/@Shageronlinestore_5328.jpg
# 1  2024-09-20 08:11:40+00:00                                 NaN
# 2  2024-09-20 05:23:18+00:00                                 NaN
# 3  2024-09-20 05:21:14+00:00  photos/@Shageronlinestore_5325.jpg
# 4  2024-09-19 13:54:46+00:00  photos/@Shageronlinestore_5323.jpg
#
#                                             tokenize
# 0  [3, \n\nእስከ, 260°, ሙቀት, መቆቆም, የሚችል\n     , \n ...
# 1  [\n\n, ጊዜ, ቆጣቢ, ስላይስ, ማድረጊያ, \n , ለእጅ, ሴፍቲ, ተመ...
# 2  [\n      , \n\n, ,, ,, -, \n\n, \n, ,, ,, ,, ,...
# 3  [\n      , \n\n, ,, ,, -, \n\n, \n, ,, ,, ,, ,...
# 4  [31, ,,, \n\n       , ዋጋ, :-3000ብር\n\nውስን, ፍሬ,...

# %%
df.head()
# Out:
#    Unnamed: 0        Channel Title    Channel Username    ID  \
# 0           5  Sheger online-store  @Shageronlinestore  5328
# 1           6  Sheger online-store  @Shageronlinestore  5327
# 2           7  Sheger online-store  @Shageronlinestore  5326
# 3           8  Sheger online-store  @Shageronlinestore  5325
# 4          10  Sheger online-store  @Shageronlinestore  5323
#
#                                              Message  \
# 0  3   \n\nእስከ 260° ሙቀት መቆቆም የሚችል\n      \n      ...
# 1   \n\n ጊዜ ቆጣቢ ስላይስ ማድረጊያ \n  ለእጅ ሴፍቲ ተመራጭ\n  ለድ...
# 2      \n          \n\n  ,  ,   - \n\n           ...
# 3      \n          \n\n  ,  ,   - \n\n           ...
# 4    31    ,, \n\n        ዋጋ:-3000ብር\n\nውስን ፍሬ ነው...
#
#                         Date                          Media Path  \
# 0  2024-09-20 11:50:02+00:00  photos/@Shageronlinestore_5328.jpg
# 1  2024-09-20 08:11:40+00:00                                 NaN
# 2  2024-09-20 05:23:18+00:00                                 NaN
# 3  2024-09-20 05:21:14+00:00  photos/@Shageronlinestore_5325.jpg
# 4  2024-09-19 13:54:46+00:00  photos/@Shageronlinestore_5323.jpg
#
#                                             tokenize
# 0  [3, \n\nእስከ, 260°, ሙቀት, መቆቆም, የሚችል\n     , \n ...
# 1  [\n\n, ጊዜ, ቆጣቢ, ስላይስ, ማድረጊያ, \n , ለእጅ, ሴፍቲ, ተመ...
# 2  [\n      , \n\n, ,, ,, -, \n\n, \n, ,, ,, ,, ,...
# 3  [\n      , \n\n, ,, ,, -, \n\n, \n, ,, ,, ,, ,...
# 4  [31, ,,, \n\n       , ዋጋ, :-3000ብር\n\nውስን, ፍሬ,...

# %%
df.to_csv("../data/tokenized_data.csv")
